# %%
import sysimport osimport matplotlib.pyplot as plt# Add the scripts to pathscripts_path = os.path.abspath(os.path.join(os.getcwd(), '../scripts'))sys.path.insert(0, scripts_path)from load_vtx import load_vtx_file
# Out:
#   Cell In[1], line 1
#     import sysimport osimport matplotlib.pyplot as plt# Add the scripts to pathscripts_path = os.path.abspath(os.path.join(os.getcwd(), '../scripts'))sys.path.insert(0, scripts_path)from load_vtx import load_vtx_file
#                      ^
# SyntaxError: invalid syntax

# %%
# Load a VTX filefile_path = os.path.abspath(os.path.join(os.getcwd(), '../data/sample-recordings/up_hawk.vtx'))vtx_data = load_vtx_file(file_path)# Print the headerprint(vtx_data['header'])

# %%
# Plot the raw accelerometer dataplt.figure(figsize=(15, 5))plt.plot(vtx_data['samples']['time_sec'], vtx_data['samples']['accel_x'], label='accel_x')plt.plot(vtx_data['samples']['time_sec'], vtx_data['samples']['accel_y'], label='accel_y')plt.plot(vtx_data['samples']['time_sec'], vtx_data['samples']['accel_z'], label='accel_z')plt.xlabel('Time (s)')plt.ylabel('Acceleration (m/s^2)')plt.title('Raw Accelerometer Data')plt.legend()plt.grid(True)plt.show()
